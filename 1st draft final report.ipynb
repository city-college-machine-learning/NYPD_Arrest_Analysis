# %% [markdown]
# #                           New York Police Department Arrest Data
#
#
#                                                        FINAL REPORT
#
#
#
#
# <img src="crime.jpg" width="200" height="200"/>
#
#
#
# Group members:
#
# Natasha Arokium
#
# Jiffar Abakoyas
#
# Bethold Owusu
#
# Thierno Diallo

# %% [markdown]
#                                                          TITLE
#
# Understanding, examining and analyzing the arrests data in New York City for the year 2019. Which were the highest level of Crimes committed that warranted an arrest? Was it a felony or was it a misdemeanor? What factors would more likely contribute to an arrest, and which Borough might be the safest?
#
#
#                                                         ABSTRACT
#
# Since we all reside in New York City which happens to be ranked # 25 for most violent crimes in the United States of America, it is imperative in the name of safety to use our knowledge as aspiring Data Scientist to delve into the data to see what can be unearth in trying to understand the who’s, how’s and why.
#
# With a population of approximately 6,068, 009 persons over 18 years old in New York, the arrest data suggests that there were 213,089 arrests made in 2019, a mere 3.5 % of the population. This information is useful for understanding the bigger picture of how to measure the crime situation in this State on a scale from 1 to 10.
#
# After normalizing the data to ensure that there were no biases or disparity between the proportions of race in conjunction with the Boroughs, it was found that 47.86 % of blacks were arrested, followed by 25% white Hispanics during the year 2019. The borough of Brooklyn saw 27.25 % arrests, the highest numbers, with Manhattan following closely with 25 %, and the Bronx respectively with 23%. From the analysis Staten Island had the least amount of arrests, a mere 5%, which suggests that it was the safest borough during the year 2019.
#
# Assaults and related offenses were the most frequently occurring level of offense, with the Bronx having the highest number of arrests in that category, followed by Manhattan and Brooklyn.  Overall, there were by far more misdemeanors (minor wrong doings), 59.41%, followed by felonies 39.07% (more violent crimes), then violations with 1.32%. To get a better understanding of why these disproportionate number came to be, a wider range of data would have had to be collected, including education level, economic status, opportunity reach etc. in the relevant neighborhoods.
#
# Although the analysis shows there were more arrests in January, the worst single day in terms of number of arrests occurred on May 2nd, 2019, with 877 arrests.  This finding was unexpected since one would expect more arrests to be made during the warm, sunny, and more comfortable months (June, July, August and early September), when more individuals are outdoors. Looking at weather.com data on that day, the day with the highest number of arrests, trying to find answers as to why, it showed that it was 77 degrees Fahrenheit and cloudy. It was however a more comfortable day overall compared to the previous days with 60, 59, and 55 degrees Fahrenheit respectively. In such a case is easy to assume that because of the reasonably lovely day, with all the excitement, more people came out, and more arrests were made.
#
# The Logistic Regression algorithm with 61% precision, 62% recall, and 57% F1 score was the best performing algorithm that predicted whether the level of crime was that of a misdemeanor or that of a felony, trained and tested with the features, age group, race, sex, borough of the arrested, and precinct where the arrest occurred.

# %% [markdown]
#                                                     INTRODUCTION
#
# Since safety is top priority for most of us, knowing and understanding the arrest statistics and causes of crimes in our environment, surrounding neighborhoods, and State should be of paramount importance. With this in mind, we decided to research, analyze, interpret, and make predictions using the New York Police Department’s Arrest dataset for the year 2019.  It was also cited in the USA Today article, Dangerous States, Jan 2020, that New York ranks # 25 in the United States list of cities with the most violent crime rates, so that made the choice of looking at the crime situation even more compelling.
#
# The NYPD’s arrest dataset is comprised of eighteen (18) features, ranging from the perpetrators age group, race, sex, arrest borough, level of arrest, offense description, arrest precinct, arrest date and other closely related data. The arrest data is collected from the five boroughs in New York, namely Brooklyn, the Bronx, Manhattan, Queens and Staten Island. Preliminary analysis determined that Staten island had the least amount of crimes, and as such was deemed the safest borough in 2019, followed by Manhattan, the Bronx and Queens. On the other hand, Brooklyn saw the highest number of arrests, with Misdemeanor having the highest ranking with reference to the level of offense.
#
# After undertaking the task of cleaning the data as a part of the exploratory data analysis process, varying visualization tools will be created to highlight and present important finding and summaries for all features and data. These visualizations will range from showing several bar graphs and charts laced with very important and interesting findings, that will be used to answer fundamentals of how, why, when and who questions. In addition to examining and trying to make sense of the data, we will also test several machine learning algorithms to ascertain the one with the best performance for making our prediction on which level of offence (felony, misdemeanor) is more likely to occur given characteristics such as age, race, gender, borough, and precinct of the arrestee.

# %% [markdown]
# Our main machine learning task was to predict the level of crime committed from other descriptions of the crime. We think this is important to help us identify what factors are important in knowing that a felony will occur. If the level of crime can’t be predicted from other features of the crime, then that will also be important information to note.
#
# To do better machine learning, we first did the following EDA to understand the data, with a focus on level of crime(misdeameanor, felony).

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
#
#                                                     THE DATA
#
# The data was collected from https://data.cityofnewyork.us/Public-Safety/NYPD-Arrest-Data-Year-to-Date-/uip8-fykc, open source data. Each record represents an arrest effected in NYC by the NYPD and includes information about the type of crime, the location, date of the enforcement and the suspects demographics.
#
#
# Discription of the variables:
#
# <font color = 'red' > ARREST_KEY: Randomly generated persistent ID for each arrest
#
# ARREST_DATE: Exact date of arrest for the reported event
#
# PD_CD: Three digit internal classification code (more granular than
# Key Code)
#
# PD_DESC: Description of internal classification corresponding with PD
# code (more granular than Offense Description)
#
# KY_CD: Three digit internal classification code (more general
# category than PD code)
#
# OFNS_DESC: Description of internal classification corresponding with KY
# code (more general category than PD description)
#
# LAW_CODE: Law code charges corresponding to the NYS Penal Law,
# VTL and other various local laws
#
# LAW_CAT_CD: Level of offense: felony, misdemeanor, violation
#
# ARREST_BORO: Borough of arrest. B(Bronx), S(Staten Island), K(Brooklyn),
# M(Manhattan), Q(Queens)
#
# ARREST_PRECINCT: Precinct where the arrest occurred
#
# JURISDICTION_CODE: Jurisdiction responsible for arrest. Jurisdiction codes
# 0(Patrol), 1(Transit) and 2(Housing) represent NYPD whilst
# codes 3 and more represent non NYPD jurisdictions
#
# AGE_GROUP: Perpetrator’s age within a category
#
# PERP_SEX: Perpetrator’s sex description
#
# PERP_RACE: Perpetrator’s race description
#
# X_COORD_CD: Midblock X-coordinate for New York State Plane
# Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)
#
# Y_COORD_CD: Midblock Y-coordinate for New York State Plane
# Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)
#
# Latitude: Latitude coordinate for Global Coordinate System, WGS
# 1984, decimal degrees (EPSG 4326)
#
# Longitude: Longitude coordinate for Global Coordinate System, WGS
# 1984, decimal degrees (EPSG 4326)
#
# </font>
#
#
# This website https://www1.nyc.gov/site/nypd/stats/reports-analysis/crime-enf.page, provide additional statistics and analysis specifically focused on race and ethnicity in New York City.
#
#
# There were 213,089 rows in our dataset, and the distribution of the level of crime was as follows. The original dataset consisted of 17 features and 1 target column. Out of the 17 features, we used the following 8 columns for our classification model:
# ![image.png](attachment:image.png)
#
#
#             Table 1: Column names used in our classification task. (Level of Offense is our target variable)

# %% [markdown]
#                                                     THE TARGET
#
# The target class had five classes: Felony, Misdemeanor, Infraction, Violation and Unknown. Since over 95% of the data belonged to the felony or misdemeanor class, we dropped the other three classes before training our classifiers. The two classes were split 60/40 between misdemeanor and felony respectively.
#
# ![image.png](attachment:image.png)
#
#                                       Figure 1: Number of arrests by level of crime

# %% [markdown]
# We did visualization on some of the feature columns in order to determine how useful they would be towards our classification model. Among them is borough,
#
#
#                                                         THE FIVE BOROUGHS
#
#
# ![image.png](attachment:image.png)
#
#
#                                                 Figure 2: Number of arrests by Borough
#
# Above it shows that crime levels by type of crime defer by borough. We expect then that the borough will be a useful feature in predicting the level of crime.

# %% [markdown]
#                                                           AGE GROUPS
#
#
# ![image.png](attachment:image.png)
#
#                                                Figure 3: Age and level of crime
#
# Age showed significant variability in terms of the number of crimes and the types of crime. This was another feature of importance in distinguishing between types of crimes.

# %% [markdown]
#                                                         GENDER
#
#
#
# ![image.png](attachment:image.png)
#
#
#                                             Figure 4: Gender and level of crime
#
#
# Visualization show that there were 4 times more males being arrested than females. The Green bar indicates that more males were arrested for misdeamoenors for the year 2019. Our eda shows the break down of the counts and percentage below.
#
# M	    173964	     81.64%
#
# F	    39125	     18.36%

# %% [markdown]
# ![image.png](attachment:image.png)
#
#                                     Figure 5: Race by level of Crime
#
#
# The analysis shows that more blacks committed both misdeamonors and felonies in New York City for the year 2019. It coincides with the analysis that blacks also had the highest percentage of arrests.
#
#
# BLACK	                   101979	47.86%,
#
# WHITE HISPANIC	           53265	25.0%,
#
# WHITE	                   25284	11.87%,
#
# BLACK HISPANIC	           18550	8.71%,
#
# ASIAN / PACIFIC ISLANDER   12013	5.64%,
#
# UNKNOWN	                   1401	    0.66%,
#
# AMERICAN INDIAN/ALASKAN NATIVE	597	0.28%,

# %% [markdown]
#
#
# ![image.png](attachment:image.png)
#
# This revelation was quite suprising, since no-one expected to see that the month with the highest number of  arrests would be in January, not only is it in the heart of winter, but one of the coldest months of the year. The warmer the month(June, July, August, September) the more persons linger outside, and more than likely more arrests should occur.
#
#                                          Figure 6. Crimes by Month

# %% [markdown]
# # Machine Learning

# %% [markdown]
#                                           Methods and Evaluation
#
# We created the following classifier models and trained them on our data and tested them using a separate testing set. The following are our results:
#
#
#
# Classifier	              Precision 	   Recall	     F1-Score	  Comment
# Dummy	                  0.52	           0.52	         0.52	      Approximates coin toss
# Logistic Regression (LR)  0.61	           0.62	         0.57	      Slightly improved
# Logistic Regression (PCA) 0.61	           0.62	         0.56	      Dimensions reduced by 70%. Accuracy same.
# SVM                       0.61	           0.62	         0.57	      Same as LR
# Decision Tree	          0.59	           0.60	         0.59	      Same as LR
# Random Forest 	          0.61	           0.62	         0.57	      Same as LR
# Random Forest, PCA	      0.61	           0.62	         0.56	      Same as LR
#
#
#                             Table 2: Classifier models and prediction results on test set

# %% [markdown]
#                                                             PCA
#
# We used PCA in order to see both whether it is able to significantly reduce our features, as well as improve our accuracy.
#
# ![image.png](attachment:image.png)
#
#                                     Figure 5: Principal Component Analysis (50 components)
#
# PCA was able to allow us to reduce the number of columns from 150 to 50, and still maintain up to 90% of the variability of the data. This was a welcome computational and storage advantage. Nevertheless, it was not useful at increasing the accuracy of our classifiers. We performed PCA based classification on both Random Forest and Logistic Regression (Results on Table-2 above).
# Since our classifiers performed similarly, we selected logistic regression for further analysis using hyperparameter tuning in an attempt to reach higher levels of accuracy. Nevertheless, the prediction was not improved by any significant margin. Using 5-fold cross validation on gridsearchCV of varies learning rates and regularization values, the best result was 0.63 accuracy (std 0.003).

# %% [markdown]
#
#                                         RANDOM FOREST FOR FEATURE IMPORTANCE
#
# We also used Random Forest for Feature Importance. We were able to look at the top features for the classifier.
#
# ![image.png](attachment:image.png)
#
#                                 Figure 3: Top 20 features from Random Forest Feature Importance
#
# We see above that age and month provide some indication to the classifier, but their importance values are less than 5 percent (age-group being in 25 to 44 being the feature of highest importance).

# %% [markdown]
#
#                                                       CONCLUSION
#
# After employing different classifier models on the dataset, it is safe to conclude that the dataset does not have rich features that allow for higher accuracy at the prediction of the level of crime. We are led to believe that it is not possible to predict the level of crime committed by a perpetrator from looking at the characteristics in our features.

# %% [markdown]
#
#                                                    REFERENCE
#
# MacDonald, John; The Effects of Local Police Surges on Crime and Arrests in New York City; PloS One; June 2016
#
# NYPD Crime and Enforcement Activity Reports; https://www1.nyc.gov/site/nypd/stats/reports-analysis/crime-enf.page
#
# Patternizr; https://statescoop.com/how-the-nypd-is-using-machine-learning-to-spot-crime-patterns/
#
# Southall, Ashley; Crime in New York City Plunges to a Level Not Seen Since the 1950s; Dec 2017; https://www.nytimes.com/2017/12/27/nyregion/new-york-city-crime-2017.html

# %% [markdown]
# CONTRIBUTION TO THE PROJECTS
#
# Natasha Arokium (approximately 15 - 20 hours of work)
#
# 1. Created github account for the project
# 2. Wrote the 1st draft for the Proposal, title, abstract, Introduction and data for the final report.
# 3. Combined markdowns from other group members
# 4. Performed complete EDA on the data, including cleaning, and showing visualizations with approximately 21 different analysis.
# 5. Used K-means clustering to group data points together that minimizes differences between the data points in the same groups   (Level of offence)
# 6. Prepared final updated Presentation slides in Powerpoint
#
# Jiffar Abakoyas
# Bethold Owusu
# Thierno Diallo

# %% [markdown]
# note: Guys i started the 'Data' section, but it needs to be completed. He is asking for eda etc. i'm not sure if he wants our codes in this notebook, or it should be in a separate notebook. We have to ensure that there is a discription under every visualization that we created. check out his grading rubric on blackboard.
